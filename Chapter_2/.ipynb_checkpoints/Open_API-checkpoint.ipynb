# %%
import json

data = """
{
    "lastBuildDate": "Thu, 06 May 2021 15:05:24 +0900",
    "total": 71769,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "네오리젠바이오텍, 더마 코스메틱 브랜드 ‘제너<b>렉스</b>’ 홈쇼핑 런칭",
            "originallink": "https://biz.chosun.com/industry/industry_general/2021/05/06/K5EPUX6G3BHSXOTBHCZL2YCSEQ/?utm_source=naver&utm_medium=original&utm_campaign=biz",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=366&aid=0000713117",
            "description": "서울대학교 연구진이 설립한 바이오기업 ㈜네오리젠바이오텍(CEO 서정민)의 고기능성 더마 코스메틱 브랜드 ‘제너<b>렉스</b>(GENEREX)’가 ‘더마톡스 리프팅 콤플<b>렉스</b> 앰플’을 홈쇼핑을 통해 런칭한다. ‘더마톡스 리프팅... ",
            "pubDate": "Thu, 06 May 2021 14:41:00 +0900"
        },
        {
            "title": "고양이분양샵 '제나캣', 다품종묘 5월 이벤트로 분양 진행",
            "originallink": "https://www.dailysecu.com/news/articleView.html?idxno=123925",
            "link": "https://www.dailysecu.com/news/articleView.html?idxno=123925",
            "description": "부산 매장에서는 브리티쉬숏헤어 고양이, 아메리칸컬 고양이, 러시안블루 등과 함께 희귀묘종인 데본<b>렉스</b>, 싱가푸라도 만나볼 수 있다. 관계자는 &quot;부산 지역뿐만 아니라 대전 및 인천 등 다양한 지역에서 문의가 급증하고... ",
            "pubDate": "Thu, 06 May 2021 14:36:00 +0900"
        },
        {
            "title": "안마의자 브랜드샵 방방, 가정의 달 맞이 신제품 세일 이벤트 진행",
            "originallink": "https://www.dailysecu.com/news/articleView.html?idxno=123888",
            "link": "https://www.dailysecu.com/news/articleView.html?idxno=123888",
            "description": "케어<b>렉스</b>를 포함한 다양한 브랜드의 신제품을 할인된 가격에 판매하는 이벤트를 진행한다. 순수 국내 브랜드인 케어<b>렉스</b>는 국내에 최적화된 유통 및 A/S를 바탕으로 국내 소비자들에게 건강하고 아름다은 삶을... ",
            "pubDate": "Thu, 06 May 2021 10:02:00 +0900"
        },
        {
            "title": "올해 9개 신약에 건강보험 적용됐다",
            "originallink": "http://www.mdtoday.co.kr/mdtoday/index.html?no=419719",
            "link": "http://www.mdtoday.co.kr/mdtoday/index.html?no=419719",
            "description": "‘에피디올<b>렉스</b> 내복액’ ▲노보노디스크제 ‘줄토피플<b>렉스</b>터치주’ ▲씨에스엘베링 등 이다. 이중 다케다제약의 ‘제줄라캡슐’을 제외한 나머지는 모두 신규 등재 약제다. 또한 지난 2월 1일자로 에자이의... ",
            "pubDate": "Thu, 06 May 2021 07:14:00 +0900"
        },
        {
            "title": "휴젤, 창립 20주년 캐릭터 ‘허그와 알루&amp;<b>렉스</b>’ 론칭",
            "originallink": "http://www.cnbnews.com/news/article.html?no=490343",
            "link": "http://www.cnbnews.com/news/article.html?no=490343",
            "description": "▲ CNB뉴스, CNBNEWS, 씨앤비뉴스 휴젤의 창립 20주년 캐릭터 허그와 알루&amp;<b>렉스</b> (사진=휴젤) 휴젤이 ‘건강한... (Alu), <b>렉스</b>(Lax) 캐릭터 3종을 개발했다. 휴젤이 개발한 캐릭터 3종은 ‘보투리누스 톡시느’ 행성 국립연구소... ",
            "pubDate": "Thu, 06 May 2021 07:10:00 +0900"
        },
        {
            "title": "[PWS] 우승 열기 그대로! 젠지, 첫 매치서 파이널로 퇴근(종합)",
            "originallink": "http://www.inven.co.kr/webzine/news/?news=255454&iskin=esports",
            "link": "https://sports.news.naver.com/news.nhn?oid=442&aid=0000133591",
            "description": "가장 먼저 화려한 수류탄 활용을 선보인 선수는 다나와의 '<b>렉스</b>'였다. 정교한 수류탄 활용으로 세 명씩 쓰러뜨리는 기염을 플레이를 펼쳤다. 하지만 다나와의 흐름은 TOP4에게 저지당하며 오래가지 못했다. 그 자리는... ",
            "pubDate": "Wed, 05 May 2021 23:21:00 +0900"
        },
        {
            "title": "[오피셜] '인종차별성 발언' 레만, 헤르타 이사회에서 퇴출",
            "originallink": "https://www.goal.com/kr/뉴스/a/nqoilhvccml412kl3pj4goea9",
            "link": "https://sports.news.naver.com/news.nhn?oid=216&aid=0000113571",
            "description": "그는 선수 시절 거친 플레이와 거침없는 발언을 일삼아 영화 매드<b>렉스</b>에서 따온 '미치광이 옌스(Mad Jens)'라는 애칭으로 불렸다. 실제 그는 선수 경력 동안 7회나 퇴장을 당하면서 골키퍼 부문 역대 최다 퇴장자로 유럽... ",
            "pubDate": "Wed, 05 May 2021 22:37:00 +0900"
        },
        {
            "title": "휴젤, 창립20주년 맞아 주력 제품 상징 캐릭터 론칭",
            "originallink": "http://www.kado.net/news/articleView.html?idxno=1072158",
            "link": "http://www.kado.net/news/articleView.html?idxno=1072158",
            "description": "휴젤은 '건강한 아름다움'을 전달하는 기업의 아이덴티티를 투영시킨 '허그(Hug),알루(Alu),<b>렉스</b>(Lax)' 캐릭터... 휴젤 관계자는 &quot;보툴리눔 톡신 제제 '보툴<b>렉스</b>'와 HA필러 브랜드 '더채움'을 효과적으로 노출시키고 '메디컬... ",
            "pubDate": "Wed, 05 May 2021 14:02:00 +0900"
        },
        {
            "title": "휴젤, 창립 20주년 기념 캐릭터 3종 공식 론칭",
            "originallink": "http://www.mediapen.com/news/view/625045",
            "link": "http://www.mediapen.com/news/view/625045",
            "description": "(Alu), <b>렉스</b>(Lax) 캐릭터 3종을 개발했다. 향후 국내외 마케팅 활동을 고려해 휴젤 기업의 연상시키면서도 해외... 캐릭터는 ‘보투리누스 톡시느’ 행성 국립연구소 수석연구원 ‘허그’와 파트너인 ‘알루’, ‘<b>렉스</b>’가... ",
            "pubDate": "Wed, 05 May 2021 13:28:00 +0900"
        },
        {
            "title": "“10명 중 7명, 칫솔 살균해본 적 없다”…칫솔살균기 효과?",
            "originallink": "https://www.hankyung.com/economy/article/202105047491a",
            "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004541440",
            "description": "‘유토<b>렉스</b>’는 칫솔살균기 등 살균 위생에 대한 소형가전을 지속해서 연구•개발하는 제조사다. ‘유토<b>렉스</b> 칫솔살균기’는 80여 모델의 칫솔살균기를 개발·생산했으며, 대표적인 칫솔살균기 제조사로 꼽히고 있다.... ",
            "pubDate": "Wed, 05 May 2021 10:02:00 +0900"
        }
    ]
}
"""
json_data = json.loads(data)
print(json_data['items'][0]['title'])
print(json_data['items'][0]['link'])
print(json_data['items'][0]['description'])
# Out:
# 네오리젠바이오텍, 더마 코스메틱 브랜드 ‘제너<b>렉스</b>’ 홈쇼핑 런칭
# https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=004&oid=366&aid=0000713117
# 서울대학교 연구진이 설립한 바이오기업 ㈜네오리젠바이오텍(CEO 서정민)의 고기능성 더마 코스메틱 브랜드 ‘제너<b>렉스</b>(GENEREX)’가 ‘더마톡스 리프팅 콤플<b>렉스</b> 앰플’을 홈쇼핑을 통해 런칭한다. ‘더마톡스 리프팅...

# %% [markdown]
# ### 네이버OPEN API로 크롤링하기

# %%
import requests
import pprint
client_id = '8hjnTxa7N2VdEHlGFjOe'
client_secret = 'GYxF4X3eMh'

json_search = input('카테고리 : ')
a = input('검색할 단어 : ')

naver_open_api = 'https://openapi.naver.com/v1/search/{}.json?query={}'.format(json_search,a)
header_params = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}
res = requests.get(naver_open_api,headers = header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1,item['title'], item['link'])
else:
    print("Error Code:",res.status_code)
# Out:
# 카테고리 : book
# 검색할 단어 : python
# 1 Effective <b>Python</b> 2nd 이펙티브 파이썬 : 파이썬 코딩의 기술 (똑똑하게 코딩하는 법, 개정판) http://book.naver.com/bookdb/book_detail.php?bid=16876960
# 2 파이썬 딥러닝 파이토치(<b>Python</b> Deep Learning PyTorch) http://book.naver.com/bookdb/book_detail.php?bid=16778336
# 3 お仕事<b>Python</b> http://book.naver.com/bookdb/book_detail.php?bid=18990394
# 4 OpenCV-<b>Python</b>으로 배우는 영상처리 및 응용 http://book.naver.com/bookdb/book_detail.php?bid=17526674
# 5 <b>Python</b> Machine Learning (The Ultimate Guide for Beginners to Master Machine Learning with Practical Applications to Artificial Intelligence and Deep Learning with <b>Python</b>) http://book.naver.com/bookdb/book_detail.php?bid=20471613
# 6 <b>Python</b> Machine Learning (The Ultimate Guide for Beginners to Master Machine Learning with Practical Applications to Artificial Intelligence and Deep Learning with <b>Python</b>) http://book.naver.com/bookdb/book_detail.php?bid=20471614
# ...

# %%
import requests
import pprint
client_id = '8hjnTxa7N2VdEHlGFjOe'
client_secret = 'GYxF4X3eMh'

a = input('검색할 단어 : ')

naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query={}&display=100&start=1'.format(a)
header_params = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}
res = requests.get(naver_open_api,headers = header_params)

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print(index + 1,item['title'], item['link'])
else:
    print("Error Code:",res.status_code)
# Out:
# 검색할 단어 : sk
# 1 R&amp;D 비용 감소에 가려진 한미약품 1Q 실적 부진 http://www.straightnews.co.kr/news/articleView.html?idxno=105267
# 2 ‘에어본’ 전희철 <b>SK</b> 감독 취임…스타 출신 잔혹사, 이번엔? https://ilyo.co.kr/?ac=article_view&entry_id=400456
# 3 '장밋빛' 전망 수소경제...K수소, 액화수소 시장 선점 속도 https://www.etoday.co.kr/news/view/2023309
# 4 순천 해룡면 공영차고지, 7일부터 임시개방 http://www.gwangnam.co.kr/read.php3?aid=1620281607385465164
# 5 고성군, 고성형 코로나19 선제적 방역 대응 '눈길' http://www.viva100.com/main/view.php?key=20210506010001107
# 6 '지재권 면제' 국내 백신 생산 호재 되나…업계 &quot;영향 제한적&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012377050
# 7 맥쿼리, 해양에너지·서라벌도시가스 8000억원에 품는다 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004542088
# 8 <b>SK</b> Telecom partners with gene tech firm to develop AI gene analysis algo... http://eng.ajunews.com/view/20210506143406685
# 9 경기남부보훈지청, 어버이날 계기 비대면 명패 달아드리기 행사 실시 http://www.kihoilbo.co.kr/news/articleView.html?idxno=925636
# ...

# %% [markdown]
# #### 엑셀로 저장
# - 천개 불러와줌

# %%
import requests
import openpyxl

client_id = '8hjnTxa7N2VdEHlGFjOe'
client_secret = 'GYxF4X3eMh'

a = input('검색할 단어 : ')
start,num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 100
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹','제목','링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/news.json?query={}&display=100&start='.format(a) + str(start_number)
    header_params = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret':client_secret}
    res = requests.get(naver_open_api,headers = header_params)

    if res.status_code == 200:
        data = res.json()
        for index, item in enumerate(data['items']):
            print(index + 1,item['title'], item['link'])
    else:
        print("Error Code:",res.status_code)
        
excel_file.save('IT.xlsx')
excel_file.close()
# Out:
# 검색할 단어 : 미나리
# 1 &quot;한국무용·현대무용·발레 모두 섭렵&quot;…한예리, 국제현대무용제 홍보대사 됐... https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=477&aid=0000298136
# 2 64년 연기 인생 안성기 &quot;운동으로 늘 같은 몸무게 유지&quot; https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=009&aid=0004790121
# 3 [이슈큐브] 'K-할머니' 전성시대…광고·예능·유튜브서 인기 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=422&aid=0000483913
# 4 한예리, 제40회 국제현대무용제 홍보대사 위촉 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=021&aid=0002470060
# 5 순천시, 우리동네 숨은 영웅 찾아봐요 http://www.gwangnam.co.kr/read.php3?aid=1620281612385464164
# 6 [인터뷰] '아들의 이름으로' 안성기 &quot;봉준호·윤여정 수상, 기세 계속 이어갔... http://www.slist.kr/news/articleView.html?idxno=248958
# 7 어린이날에만 32만명 활기 찾은 극장가…지난해보다 3배 https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=106&oid=005&aid=0001436957
# 8 [박소정 큐레이터의 #위드아트] 수교 60주년, '영화 <b>미나리</b>'식 공감법 http://www.m-i.kr/news/articleView.html?idxno=827179
# ...

# %% [markdown]
# ### 정부제공 공공 데이터 Open API 사용
# - 한국환경공단_에어코리아_대기오염정보
# - https://data.go.kr/data/15073861/openapi.do

# %%
import requests

service_key = 'k843MsctCfKXzXdaTNgsDy1E3P0FjqIAIbLJsl2%2FPztjbvYnvD8epkOT2KnJ6uBwpOvpHUNqILkPpMh910yeKA%3D%3D'
params = '&numOfRows=10&pageNo&sidoName=부산'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey=' + service_key + params

res = requests.get(open_api)

print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>77</khaiValue>
#         <so2Value>0.002</so2Value>
#         <coValue>0.2</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>67</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>부산</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-05-06 16:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.018</no2Value>
#         <stationName>광복동</stationName>
#         <pm10Grade>2</pm10Grade>
#         <o3Value>0.043</o3Value>
#       </item>
#       <item>
#         <so2Grade/>
#         <coFlag>점검및교정</coFlag>
#         <khaiValue>-</khaiValue>
#         <so2Value>-</so2Value>
# ...

# %%
import requests
from bs4 import BeautifulSoup

service_key = 'k843MsctCfKXzXdaTNgsDy1E3P0FjqIAIbLJsl2%2FPztjbvYnvD8epkOT2KnJ6uBwpOvpHUNqILkPpMh910yeKA%3D%3D'
params = '&numOfRows=10&pageNo&sidoName=부산'
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey=' + service_key + params

res = requests.get(open_api)
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find_all('item')
for item in data:
    stationname = item.find('stationname')
    pm10grade = item.find('pm10grade')
    print(stationname.get_text(), pm10grade.get_text())
# Out:
# 광복동 2
# 초량동 2
# 태종대 2
# 청학동 2
# 전포동 2
# 온천동 2
# 명장동 2
# 대연동 2
# 학장동 2
# 덕천동 2

# %%
import requests
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'
serviceKey = '?serviceKey=k843MsctCfKXzXdaTNgsDy1E3P0FjqIAIbLJsl2%2FPztjbvYnvD8epkOT2KnJ6uBwpOvpHUNqILkPpMh910yeKA%3D%3D'
returnType = '&returnType=json'
numOfRows = '&numOfRows=100'
sidoName = '&sidoName=서울'
res = requests.get(open_api+serviceKey+returnType+numOfRows+sidoName)
#print(res.text)
if res.status_code == 200:
    data = res.json()
    print(data['response']['body']['items'])
    # for index, item in enumerate(data['items']):
    #     print (index, item)
else:
    print("Error Code:", res.status_code)
# Out:
# [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '94', 'so2Value': '0.004', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '97', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '중구', 'pm10Grade': '2', 'o3Value': '0.073'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '99', 'so2Value': '0.003', 'coValue': '0.8', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '110', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'so2Flag': None, 'dataTime': '2021-05-06 16:00', 'coGrade': '1', 'no2Value': '0.033', 'stationName': '한강대로', 'pm10Grade': '2', 'o3Value': '0.036'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.005', 'coValue': '0.5', 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '96', 'khaiGrade': '2', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'so2Flag'
# ...
