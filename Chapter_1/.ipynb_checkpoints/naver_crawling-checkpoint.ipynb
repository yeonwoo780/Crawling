# %% [markdown]
# ### 네이버 쇼핑 사이트 BEST100

# %% [markdown]
# #### 인기검색어 들고오기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#popular_srch_lst > li > span.txt')
for item in items:
    print(item.get_text())
# Out:
# 어버이날 용돈박스
# 면도기
# 카네이션
# 어버이날 선물
# 크록스 키즈
# 닌텐도 스위치
# 마스크
# 크록스
# 에어팟 프로
# 어버이날 카네이션

# %% [markdown]
# #### 위의 li태그 공통적인 부분으로 추측가능( popular_srch_lst > li > span.txt )
# - popular_srch_lst > li.on > span.txt > a
#  - 어버이날 용돈박스
#
# - popular_srch_lst > li:nth-child(2) > span.txt > a
#  - 면도기
#
# - popular_srch_lst > li:nth-child(3) > span.txt > a
#  - 카네이션

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('a._popular_srch_lst_li') 
for item in items:
    print(item.get_text())
# Out:
# 어버이날 용돈박스
# 면도기
# 카네이션
# 어버이날 선물
# 크록스 키즈
# 닌텐도 스위치
# 마스크
# 크록스
# 에어팟 프로
# 어버이날 카네이션

# %% [markdown]
# #### 패션의류

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#productListArea > ul > li:nth-child(1) > p > a') 
for item in items:
    print(item.get_text())
# Out:
# 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#productListArea > ul > li:nth-child(2) > p > a') 
for item in items:
    print(item.get_text())
# Out:
# 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#productListArea > ul > li > p > a') 
for item in items:
    print(item.get_text())
# Out:
# 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 지오다노 여 TR 블레이저 솔리드 371501
# 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 나이키 기능성 드라이핏 반팔티 레전드 718...
# 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 아디다스 오버핏 데일리 바람막이 우븐소재...
# 지오다노 여 나일론 조거팬츠 411522
# 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 아노락 바람막이 후드집업 반바지 트레이닝...
# 지오다노 지오다노 여 레인코트 371513
# 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 이경희 란제리 레이스 슬립 가운세트
# SOUP 기본 린넨 자켓 SW5JK80
# 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# 나이키 스우시 반팔티 827021-100
# 아디다스 FW19 T19 트랙 트레이닝 팬츠 DW6...
# 나이키 NSW 클럽 크루 프렌치테리 맨투맨 남...
# 리스트 기본 자켓 자켓 TWWJKK62010
# 아디다스 3D 트레포일 트랙팬츠 GN3534
# ...

# %% [markdown]
# #### 패션잡화

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#productListArea > ul > li > p > a') 
for item in items:
    print(item.get_text())
# Out:
# 아디다스 알파바운스 슬라이드 슬리퍼 BA87...
# 크록스 바야밴드 클로그 205089-126
# 몽블랑 사토리얼 반지갑 6cc 113215
# 크록스 크록밴드 클로그 슬리퍼 샌들 크림 ...
# MLB 루키 볼캡 뉴욕양키스 32CP77011
# 나이키 팬텀 데이브레이크 써밋화이트 크림...
# 나이키 헤리티지 힙색 BA5750-010
# 나이키 헤리티지86 퓨추라 워시드캡 913011...
# 아디다스 알파바운스 슬라이드 B41720
# 크록스 라이트라이드 클로그 204592-4CC
# 컨버스 척테일러 1970S 하이 스니커즈화 16...
# 나이키 에어 포스 1 07 CW2288-111
# 헬렌카민스키 비앙카 HSSHE100110
# 나이키 데이브레이크 써밋화이트 CK2351-10...
# 디올 오블리크 새들 플랫 카드지갑
# 나이키 헤리티지 86 퓨추라 워시드 캡 9130...
# 크록스 바야밴드 클로그 7가지 컬러 205089
# 생로랑 YSL 모노그램 카드지갑 BOW01 1000 ...
# 나이키 우먼스 에어맥스 엑시스 러닝화 AA2...
# 나이키 국내매장판 데이브레이크 써밋화이트...
# 몽블랑 블랙 레더 스트랩 벨트 38157
# 나이키 운동화 우먼스 코트 레거시 뮬 DB39...
# 크록스 바야밴드 클로그 205089
# 나이키 써밋화이트 우먼 TC7900 DD9682-100
# 지샥 지코스모 지얄오크 정품보증서 쇼핑백...
# 캉골 워시드 버킷햇 K4224HT
# 나이키 우먼스 레볼루션 5 BQ3207-002
# 나이키 에어 테일윈드79 487754-100
# 나이키 첼린저 OG 라이트본 런닝화 CW7645-...
# 나이키 레거시 91 테크 스우시 캡 볼캡 모자...
# 나이키 에어맥스 엑시스 AA2146-100
# 뉴발란스 남녀공용 토앤토 NB X T T FLIPFL...
# 아디다스 공용 알파바운스 슬라이드 슬리퍼...
# 뉴발란스 NEW BALANCE 슬리퍼 unisex SD150...
# ...

# %% [markdown]
# #### 4개 카테고리 크롤링

# %%
import requests
from bs4 import BeautifulSoup

site_list= ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003',]

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    items = soup.select('#productListArea > ul > li > p > a')
    print(site,'\n')
    for item in items:
        print(item.get_text())
    print()
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
#
# 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 지오다노 여 TR 블레이저 솔리드 371501
# 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 나이키 기능성 드라이핏 반팔티 레전드 718...
# 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 아디다스 오버핏 데일리 바람막이 우븐소재...
# 지오다노 여 나일론 조거팬츠 411522
# 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 아노락 바람막이 후드집업 반바지 트레이닝...
# 지오다노 지오다노 여 레인코트 371513
# 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 이경희 란제리 레이스 슬립 가운세트
# SOUP 기본 린넨 자켓 SW5JK80
# 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# 나이키 스우시 반팔티 827021-100
# 아디다스 FW19 T19 트랙 트레이닝 팬츠 DW6...
# ...

# %%
import requests
from bs4 import BeautifulSoup

site_list= ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002',
            'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003',]

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    items = soup.select('#productListArea > ul > li > p > a')
    print(site,'\n')
    for index, item in enumerate(items) :
        print(str(index +1) + '.', item.get_text())
    print()
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
#
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
# 11. 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 12. 나이키 기능성 드라이핏 반팔티 레전드 718...
# 13. 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 14. 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 15. 아디다스 오버핏 데일리 바람막이 우븐소재...
# 16. 지오다노 여 나일론 조거팬츠 411522
# 17. 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 18. 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 19. 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 20. 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 21. 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 22. 아노락 바람막이 후드집업 반바지 트레이닝...
# 23. 지오다노 지오다노 여 레인코트 371513
# 24. 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 25. 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 26. 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 27. 이경희 란제리 레이스 슬립 가운세트
# 28. SOUP 기본 린넨 자켓 SW5JK80
# ...

# %% [markdown]
# #### 10개식 불러오기

# %%
import requests
from bs4 import BeautifulSoup

site_lite = []
for i in range(0, 4):
    a = 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=5000000'
    site_lite.append(a+str(i))

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content,'html.parser')
    items = soup.select('#productListArea > ul > li > p > a')
    print(site,'\n')
    for index, item in enumerate(items) :
        print(str(index +1) + '.', item.get_text())
        if index == 9:
            break
    print()
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
#
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
#
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001
#
# 1. 아디다스 알파바운스 슬라이드 슬리퍼 BA87...
# 2. 크록스 바야밴드 클로그 205089-126
# 3. 몽블랑 사토리얼 반지갑 6cc 113215
# 4. 크록스 크록밴드 클로그 슬리퍼 샌들 크림 ...
# 5. MLB 루키 볼캡 뉴욕양키스 32CP77011
# 6. 나이키 팬텀 데이브레이크 써밋화이트 크림...
# 7. 나이키 헤리티지 힙색 BA5750-010
# 8. 나이키 헤리티지86 퓨추라 워시드캡 913011...
# 9. 아디다스 알파바운스 슬라이드 B41720
# 10. 크록스 라이트라이드 클로그 204592-4CC
#
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002
#
# 1. 설화수 자음 2종 세트
# 2. 헤라 블랙 쿠션 15g(SPF34)
# 3. 설화수 탄력 에센셜 3종 세트
# 4. 미쟝센 헬로 버블 컬러 90g
# 5. 미쟝센 쉽고빠른 거품 염색약 80g
# 6. 설화수 순행 클렌징폼 200ml
# ...

# %% [markdown]
# ### 네이버 주식 사이트 크롤링 하기1
# - 네이버 국내 증시

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('#popularItemList > li > a') 
for item in items:
    print(item.get_text())
# Out:
# HMM
# 삼성전자
# 삼성중공업
# 카카오
# 셀트리온
# 대한항공
# LG전자
# POSCO
# KB금융
# 헬릭스미스

# %% [markdown]
# #### 주요해외지수 이름
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(1) > a
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(2) > a

# %% [markdown]
# #### 주요해외지수 상승 하락 가격
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(1) > span
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(2) > span

# %% [markdown]
# #### 주요해외지수 상승 하락 표시
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(1) > em
# #contentarea > div.box_top_submain2 > div.rgt > ul.lst_major > li:nth-child(2) > em

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.rgt > ul.lst_major > li') 
for item in items:
    print('지수이름 : ', item.find('a').get_text(), 
          '현재지수 : ',item.find('span').get_text(),
          item.find('em').get_text())
# Out:
# 지수이름 :  다우산업 현재지수 :  34,230.34 상승
# 지수이름 :   나스닥 현재지수 :  13,582.43 하락
# 지수이름 :   홍콩H 현재지수 :  10,801.70 상승
# 지수이름 :   상해종합 현재지수 :  3,460.09 상승
# 지수이름 :   니케이225 현재지수 :  29,410.08 상승

# %%
#contentarea > div.box_type_l > table > tbody > tr:nth-child(3) > td:nth-child(2) > a
#contentarea > div.box_type_l > table > tbody > tr:nth-child(4) > td:nth-child(2) > a

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.box_type_l tr td a') 
for item in items:
    print(item.get_text())
# Out:
# HMM
# 삼성전자
# 삼성중공업
# 카카오
# 셀트리온
# 대한항공
# LG전자
# POSCO
# KB금융
# 헬릭스미스
# SK하이닉스
# 텔레칩스
# 신풍제약
# STX중공업
# SK이노베이션
# 금호석유
# 호텔신라
# 아이에이
# 씨젠
# 동국제강
# 현대차
# 박셀바이오
# 두산밥캣
# 씨에스윈드
# 셀트리온헬스케어
# NAVER
# 삼성SDI
# LG화학
# 팬오션
# 현대제철

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.box_type_l  tr td a') 
for item in items:
    print(item.get_text())
# Out:
# HMM
# 삼성전자
# 삼성중공업
# 카카오
# 셀트리온
# 대한항공
# LG전자
# POSCO
# KB금융
# 헬릭스미스
# SK하이닉스
# 텔레칩스
# 신풍제약
# STX중공업
# SK이노베이션
# 금호석유
# 호텔신라
# 아이에이
# 씨젠
# 동국제강
# 현대차
# 박셀바이오
# 두산밥캣
# 씨에스윈드
# 셀트리온헬스케어
# NAVER
# 삼성SDI
# LG화학
# 팬오션
# 현대제철

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn')
soup = BeautifulSoup(res.content,'html.parser')
items = soup.select('div.box_type_l  tr td a')
for item in items:
    print(item.get_text())
# Out:
# HMM
# 삼성전자
# 삼성중공업
# 셀트리온
# 카카오
# 대한항공
# POSCO
# LG전자
# 삼성SDI
# 금호석유
# KB금융
# 셀트리온헬스케어
# 팬오션
# 한국선재
# SK하이닉스
# 현대차
# 신풍제약
# 대원미디어
# SK이노베이션
# 텔레칩스
# 동일제강
# 휴마시스
# 씨젠
# 기아
# 아이에이
# 동국제강
# LG화학
# 특수건설
# NAVER
# 호텔신라

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
options = Options()
options.headless = True
browser = webdriver.Chrome(executable_path="C:\\Users\\ad\\Downloads\\chromedriver_win32\\chromedriver.exe", options=options)
browser.get("https://finance.naver.com/sise/lastsearch2.nhn")
time.sleep(3)
tag_names = browser.find_elements_by_tag_name("table")
jusic = []
for tag in tag_names:
    jusic.append(tag.text.split("\n"))
    
jusic
# Out:
# [['항목 선택표',
#   '거래량 매수호가 거래대금(백만) 시가총액(억) 영업이익(억) PER(배)',
#   '시가 매도호가 전일거래량 자산총계(억) 영업이익증가율 ROE(%)',
#   '고가 매수총잔량 외국인비율 부채총계(억) 당기순이익(억) ROA(%)',
#   '저가 매도총잔량 상장주식수(천주) 매출액(억) 주당순이익(원) PBR(배)',
#   '      매출액증가율 보통주배당금(원) 유보율(%)'],
#  ['순위 종목명 검색비율 현재가 전일비 등락률 거래량 시가 고가 저가 PER ROE',
#   '1 HMM 2.08% 39,900 4,250 +11.92% 16,355,719 36,250 39,900 36,100 103.91 8.93',
#   '2 삼성전자 1.66% 82,300 300 -0.36% 16,846,163 81,700 82,300 81,700 21.43 9.99',
#   '3 삼성중공업 1.25% 6,000 1,160 -16.20% 83,419,885 5,660 6,420 5,620 -2.55 -33.06',
#   '4 휴마시스 0.88% 18,000 1,150 -6.01% 3,379,528 19,150 19,300 17,850 28.04 N/A',
#   '5 카카오 0.87% 115,000 500 -0.43% 3,216,464 115,000 117,500 113,500 323.94 2.70',
#   '6 셀트리온 0.76% 252,500 7,500 -2.88% 1,137,018 260,000 261,500 251,000 67.93 16.68',
#   '7 노루홀딩스우 0.64% 125,000 28,600 +29.67% 57,267 116,000 125,000 115,000 120.42 N/A',
#   '8 유바이오로직스 0.57% 37,650 6,800 +22.04% 6,034,862 30,700 38,200 30,350 -18.22 -91.23',
# ...

# %%
a = jusic[1][0]
a = a.split(' ')
a
# Out:
# ['순위',
#  '종목명',
#  '검색비율',
#  '현재가',
#  '전일비',
#  '등락률',
#  '거래량',
#  '시가',
#  '고가',
#  '저가',
#  'PER',
#  'ROE']

# %%
jusic_1 = jusic[1]
df_jusic_1 = pd.DataFrame(jusic_1)
df_jusic_1 = df_jusic_1[0].str.split(' ')
df_jusic_1=df_jusic_1.apply(lambda x: pd.Series(x))
df_jusic_1.reset_index(drop=True)
df_jusic_1 = df_jusic_1[df_jusic_1.index != 0].copy()
df_jusic_1 = df_jusic_1.drop(12, axis=1)
df_jusic_1.columns = a
df_jusic_1
# Out:
#     순위        종목명   검색비율      현재가      전일비      등락률         거래량       시가  \
# 1    1        HMM  2.08%   39,900    4,250  +11.92%  16,355,719   36,250
# 2    2       삼성전자  1.66%   82,300      300   -0.36%  16,846,163   81,700
# 3    3      삼성중공업  1.25%    6,000    1,160  -16.20%  83,419,885    5,660
# 4    4       휴마시스  0.88%   18,000    1,150   -6.01%   3,379,528   19,150
# 5    5        카카오  0.87%  115,000      500   -0.43%   3,216,464  115,000
# 6    6       셀트리온  0.76%  252,500    7,500   -2.88%   1,137,018  260,000
# 7    7     노루홀딩스우  0.64%  125,000   28,600  +29.67%      57,267  116,000
# 8    8    유바이오로직스  0.57%   37,650    6,800  +22.04%   6,034,862   30,700
# 9    9       KB금융  0.54%   57,500    4,200   +7.88%   3,164,053   54,400
# 10  10       대한항공  0.54%   27,600    1,250   +4.74%   5,926,228   26,350
# 11  11        현대차  0.48%  223,500        0    0.00%     643,134  223,000
# 12  12         씨젠  0.44%   81,900    1,500   -1.80%     618,440   83,400
# ...

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/lastsearch2.nhn')
soup = BeautifulSoup(res.content,'html.parser')


while True:
    a = input('코드 입력 : ')
    items = soup.select('td {}'.format(a))
    for item in items:
        print(item.get_text())
    
    print()
    if a == 'quit':
        break
# Out:
# 코드 입력 : a
# HMM
# 삼성전자
# 삼성중공업
# 카카오
# 셀트리온
# 대한항공
# LG전자
# POSCO
# KB금융
# 헬릭스미스
# SK하이닉스
# 텔레칩스
# 신풍제약
# STX중공업
# SK이노베이션
# 금호석유
# 호텔신라
# 아이에이
# 씨젠
# 동국제강
# 현대차
# 박셀바이오
# 두산밥캣
# 씨에스윈드
# 셀트리온헬스케어
# NAVER
# 삼성SDI
# LG화학
# 팬오션
# 현대제철
#
# 코드 입력 : quit

# %%
import lxml
import pandas as pd
df = pd.read_html('https://finance.naver.com/sise/lastsearch2.nhn',encoding='cp949')
df
# Out:
# [     0      1          2        3          4       5
#  0  거래량   매수호가   거래대금(백만)  시가총액(억)    영업이익(억)  PER(배)
#  1   시가   매도호가      전일거래량  자산총계(억)    영업이익증가율  ROE(%)
#  2   고가  매수총잔량      외국인비율  부채총계(억)   당기순이익(억)  ROA(%)
#  3   저가  매도총잔량  상장주식수(천주)   매출액(억)   주당순이익(원)  PBR(배)
#  4  NaN    NaN        NaN   매출액증가율  보통주배당금(원)  유보율(%),
#        순위       종목명   검색비율       현재가      전일비      등락률         거래량        시가  \
#  0    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
#  1    1.0       HMM  2.23%   38800.0   3150.0   +8.84%   9366783.0   36250.0
#  2    2.0      삼성전자  1.59%   82000.0    600.0   -0.73%   8175841.0   81700.0
#  3    3.0     삼성중공업  1.54%    6200.0    960.0  -13.41%  57535741.0    5660.0
#  4    4.0       카카오  1.23%  114000.0   1500.0   -1.30%   1772106.0  115000.0
#  5    5.0      셀트리온  1.04%  252000.0   8000.0   -3.08%    639776.0  260000.0
#  6    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
# ...

# %%
df[1]
# Out:
#       순위       종목명   검색비율       현재가      전일비      등락률         거래량        시가  \
# 0    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
# 1    1.0       HMM  2.23%   38800.0   3150.0   +8.84%   9366783.0   36250.0
# 2    2.0      삼성전자  1.59%   82000.0    600.0   -0.73%   8175841.0   81700.0
# 3    3.0     삼성중공업  1.54%    6200.0    960.0  -13.41%  57535741.0    5660.0
# 4    4.0       카카오  1.23%  114000.0   1500.0   -1.30%   1772106.0  115000.0
# 5    5.0      셀트리온  1.04%  252000.0   8000.0   -3.08%    639776.0  260000.0
# 6    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
# 7    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
# 8    NaN       NaN    NaN       NaN      NaN      NaN         NaN       NaN
# 9    6.0      대한항공  0.76%   27600.0   1250.0   +4.74%   3199059.0   26350.0
# 10   7.0      LG전자  0.64%  152000.0   2500.0   -1.62%    701044.0  154000.0
# ...

# %%
df_jusic = df[1].dropna()
df_jusic
# Out:
#       순위       종목명   검색비율       현재가      전일비      등락률         거래량        시가  \
# 1    1.0       HMM  2.23%   38800.0   3150.0   +8.84%   9366783.0   36250.0
# 2    2.0      삼성전자  1.59%   82000.0    600.0   -0.73%   8175841.0   81700.0
# 3    3.0     삼성중공업  1.54%    6200.0    960.0  -13.41%  57535741.0    5660.0
# 4    4.0       카카오  1.23%  114000.0   1500.0   -1.30%   1772106.0  115000.0
# 5    5.0      셀트리온  1.04%  252000.0   8000.0   -3.08%    639776.0  260000.0
# 9    6.0      대한항공  0.76%   27600.0   1250.0   +4.74%   3199059.0   26350.0
# 10   7.0      LG전자  0.64%  152000.0   2500.0   -1.62%    701044.0  154000.0
# 11   8.0     POSCO  0.61%  393500.0  17000.0   +4.52%    445797.0  380500.0
# 12   9.0      KB금융  0.59%   56800.0   3500.0   +6.57%   1661454.0   54400.0
# 13  10.0     헬릭스미스  0.57%   31700.0   3000.0  +10.45%    740806.0   28700.0
# 17  11.0    SK하이닉스  0.56%  129000.0   3000.0   -2.27%   2063886.0  130000.0
# ...

# %% [markdown]
# ### Urillib 라이브러리 사용법
# - https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/')
soup = BeautifulSoup(res.content,'html.parser')

data = soup.select('h4.card-text')
for item in data:
    print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/xxx')
if res.status_code != 200:
    print('페이지 X ')

else:
    soup = BeautifulSoup(res.content,'html.parser')

    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text().strip())
# Out:
# 페이지 X

# %% [markdown]
# #### 여러페이지 한번에 크롤링하는 기법

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    

    soup = BeautifulSoup(res.content,'html.parser')

    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# ...

# %% [markdown]
# ### 크롤링해서 엑셀파일로 데이터 저장

# %%
import openpyxl

def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    excel_sheet.column_dimensions['B'].width = 20
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in listdata:
        excel_sheet.append(item)
        
    excel_file.save(filename)
    excel_file.close()

# %%
import requests
from bs4 import BeautifulSoup

product_lists = list()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num + 1))
    

    soup = BeautifulSoup(res.content,'html.parser')

    data = soup.select('div.card')
    for item in data:
        product_name = item.select_one('div.card-body h4.card-text')
        product_date = item.select_one('div.wrapfooter span.post-date')
        product_info = [product_name.get_text().strip(), product_date.get_text()]
        product_lists.append(product_info)

# %%
product_lists
# Out:
# [['상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루', '05 Jun 2020'],
#  ['상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지', '05 Jun 2020'],
#  ['상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조', '05 Jun 2020'],
#  ['상품명: 보드래 헬로우 누빔 매트리스커버, 핑크', '05 Jun 2020'],
#  ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜', '05 Jun 2020'],
#  ['상품명: 피아블 클래식 방수 매트리스커버, 화이트', '05 Jun 2020'],
#  ['상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이', '05 Jun 2020'],
#  ['상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이', '05 Jun 2020'],
#  ['상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이', '05 Jun 2020'],
#  ['상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이', '05 Jun 2020'],
#  ['상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리', '05 Jun 2020'],
#  ['상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜', '05 Jun 2020'],
#  ['상품명: WEMAX 다용도 문옷걸이, 화이트, 1개', '05 Jun 2020'],
#  ['상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑', '05 Jun 2020'],
#  ['상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이', '05 Jun 2020'],
#  ['상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이', '05 Jun 2020'],
#  ['상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크', '05 Jun 2020'],
# ...

# %%
write_excel_template('tmp.xlsx',sheetname = '상품정보',listdata=product_lists)

# %%
import openpyxl

excel_file = openpyxl.load_workbook('tmp.xlsx')

excel_file.sheetnames
# Out:
# ['상품정보']

# %%
excel_sheet = excel_file['상품정보']

# %%
for item in excel_sheet.rows:
    print(item[0].value, item[1].value)
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루 05 Jun 2020
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지 05 Jun 2020
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조 05 Jun 2020
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크 05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜 05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트 05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이 05 Jun 2020
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이 05 Jun 2020
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이 05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이 05 Jun 2020
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리 05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜 05 Jun 2020
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개 05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑 05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이 05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이 05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크 05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜 05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트 05 Jun 2020
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트 05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루 05 Jun 2020
# ...
